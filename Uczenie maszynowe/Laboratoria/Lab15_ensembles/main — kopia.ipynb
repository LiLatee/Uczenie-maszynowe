# %%
import numpy as np
import pandas as pd
import collections
from sklearn.metrics import confusion_matrix, classification_report, balanced_accuracy_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as plt3d
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.svm import LinearSVC, SVC
import pickle
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle
from sklearn.metrics import plot_confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Zadanie 3

# %%
data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
classes_count = collections.Counter(y)
class_0_prc = classes_count[0]/(classes_count[1]+classes_count[0])
class_1_prc = 1 - class_0_prc
print("0: ", class_0_prc)
print("1: ", class_1_prc)
print(classes_count)
# Out:
# 0:  0.9805
# 1:  0.019499999999999962
# Counter({0: 9805, 1: 195})

# %%
collections.Counter(X.dtypes)
# wszystkie atrybuty liczbowe
# Out:
# Counter({dtype('float64'): 121})

# %%
mean_df = pd.DataFrame(X.mean())
std_df = pd.DataFrame(X.std())
min_df = pd.DataFrame(X.min())
max_df = pd.DataFrame(X.max())

mean_std_df = mean_df.merge(std_df, left_index=True, right_index=True)
mean_std_df["std/mean"] = mean_std_df['0_y']/mean_std_df["0_x"]
mean_std_min_df = mean_std_df.merge(min_df, left_index=True, right_index=True)
mean_std_min_max_df = mean_std_min_df.merge(max_df, left_index=True, right_index=True)

mean_std_min_max_df.columns = ['mean', "std", "std/mean", 'min', 'max']
pd.DataFrame.round(mean_std_min_max_df,decimals=4).to_csv("./data_desc.csv")
mean_std_min_max_df
# Out:
#             mean       std  std/mean       min        max
# dissim  0.008654  0.003479  0.402015  0.001044   0.024909
# el0     0.198952  0.149436  0.751114  0.008220   0.855030
# el1     0.216438  0.104618  0.483363  0.010886   0.859720
# el2     0.196187  0.094724  0.482823  0.003907   0.790770
# el3     0.190341  0.094329  0.495577  0.006795   0.894280
# ...          ...       ...       ...       ...        ...
# stat72  5.959587  5.098976  0.855592 -1.550900  26.661000
# stat73  6.001017  5.558763  0.926303 -1.696000  26.570000
# stat74  5.960492  5.058793  0.848721 -1.587800  26.645000
# stat75  6.508764  7.240256  1.112386 -1.726400  79.562000
# stat76  1.223767  0.396691  0.324156  0.115710   2.096900
#
# [121 rows x 5 columns]

# %%
collections.Counter(mean_std_min_max_df['mean']<0)
# Out:
# Counter({False: 115, True: 6})

# %%
collections.Counter((mean_std_min_max_df['max']>=0.9) & (mean_std_min_max_df['max']<=1))
# Out:
# Counter({False: 112, True: 9})

# %%
sca = StandardScaler()
X_std = sca.fit_transform(X)
X_std = pd.DataFrame(X_std, columns=X.columns)

mean_df = pd.DataFrame(X_std.mean())
std_df = pd.DataFrame(X_std.std())
min_df = pd.DataFrame(X_std.min())
max_df = pd.DataFrame(X_std.max())

mean_std_df = mean_df.merge(std_df, left_index=True, right_index=True)
mean_std_min_df = mean_std_df.merge(min_df, left_index=True, right_index=True)
mean_std_min_max_df = mean_std_min_df.merge(max_df, left_index=True, right_index=True)

mean_std_min_max_df.columns = ['mean', "std", 'min', 'max']
mean_std_min_max_df
pd.DataFrame.round(mean_std_min_max_df,decimals=4).to_csv("./data_std_desc.csv")
# mean_std_min_max_df

# %%
# Klasa większościowa to 0 ~98.05%. To byłaby trafność klasyfikatora Zero Rule.
y_pred = np.zeros(data.shape[0])
print(confusion_matrix(y, y_pred))
print(classification_report(y, y_pred))
print("balanced_accuracy_score: ", balanced_accuracy_score(y, y_pred, adjusted=False))
# Out:
# [[9805    0]
#  [ 195    0]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      9805
#            1       0.00      0.00      0.00       195
#
#     accuracy                           0.98     10000
#    macro avg       0.49      0.50      0.50     10000
# weighted avg       0.96      0.98      0.97     10000
#
# balanced_accuracy_score:  0.5
# D:\Instalowane\Programy\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sensitivity = 0/(0+3897)
specificity = 11103/(11103+0)
G_mean = pow(sensitivity*specificity,0.5)
G_mean # 0
# Out:
# 0.0

# %% [markdown]
# # Zadanie 4

# %%
sca = StandardScaler()
X_std = sca.fit_transform(X)

pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_std)

fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
plt.scatter(X_pca[y==0][:,0], X_pca[y==0][:,1], color='red', edgecolor='black')
plt.scatter(X_pca[y==1][:,0], X_pca[y==1][:,1], color='blue', edgecolor='yellow')

plt.xlabel("Pierwsza składowa: {0}% zachowanej wariancji".format(round(pca.explained_variance_ratio_[0]*100, 2)))
plt.ylabel("Druga składowa: {0}% zachowanej wariancji".format(round(pca.explained_variance_ratio_[1]*100, 2)))
plt.title("PCA z 2 składowymi - {0}% zachowanej wariancji".format(round(sum(pca.explained_variance_ratio_)*100, 2)))


plt.savefig("./rysunki/PCA_2D.png")
print(": ", sum(pca.explained_variance_ratio_))
# Out:
# :  0.3874257951278221

# %%
from matplotlib import interactive
# %matplotlib qt  
# wx, gtk, osx, tk, empty uses default

pca = PCA(n_components=3, random_state=42)
X_pca = pca.fit_transform(X_std)[:15000]

fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax = plt.axes(projection='3d')
y_5k = y[:15000]
ax.scatter3D(X_pca[y_5k==0][:,0], X_pca[y_5k==0][:,1], X_pca[y_5k==0][:,2], color='red', edgecolor='black')
ax.scatter3D(X_pca[y_5k==1][:,0], X_pca[y_5k==1][:,1], X_pca[y_5k==1][:,2], color='blue', edgecolor='yellow')

ax.set_xlabel("Pierwsza składowa: {0}% zachowanej wariancji".format(round(pca.explained_variance_ratio_[0]*100, 2)))
ax.set_ylabel("Druga składowa: {0}% zachowanej wariancji".format(round(pca.explained_variance_ratio_[1]*100, 2)))
ax.set_zlabel("Trzecia składowa: {0}% zachowanej wariancji".format(round(pca.explained_variance_ratio_[2]*100, 2)))
plt.title("PCA z 3 składowymi - {0}% zachowanej wariancji".format(round(sum(pca.explained_variance_ratio_)*100, 2)))

# ax.view_init(10, 0)
# plt.savefig("./rysunki/PCA_3D.svg")
print(": ", sum(pca.explained_variance_ratio_))
# Out:
# :  0.4756714787605891

# %% [markdown]
# # Zadanie 6

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
# tuned_parameters = [{'clf': (RandomForestClassifier(random_state=42), )},
#                    {'clf': (AdaBoostClassifier(random_state=42), )},
#                     {'clf': (AdaBoostClassifier(random_state=42), ),
#                         'clf__base_estimator': DecisionTreeClassifier()}
#                    {'clf': (VotingClassifier(), )},
#                    {'clf': (StackingClassifier(), )}]

classifiers = [('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]

tuned_parameters_list = [{},
                         {
                             'clf__base_estimator': [DecisionTreeClassifier(random_state=42),
                                                     SVC(random_state=42),
                                                    MLPClassifier(random_state=42),
                                                    GaussianNB(),
                                                    QuadraticDiscriminantAnalysis()]
                         },
                         {
                             'clf__estimators': [[[('DTC', DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         },
                                                  {
                             'clf__estimators': [[[('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         }
                         
                   
                   ]
                   
classifiers_list = [
    RandomForestClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    VotingClassifier(n_jobs=6, estimators=[]),
    StackingClassifier(n_jobs=6, estimators=[])
    
]
classifiers_names = [
    'RandomForestClassifier',
    'AdaBoostClassifier',
    'VotingClassifier',
    'StackingClassifier'
    
]

scoring = {'gmean': make_scorer(gmean)}
score = 'gmean'


for i in range(len(classifiers_list)):
    start = time.time()
    pipe = Pipeline(steps=[('clf',classifiers_list[i])])
    
    print("# Tuning hyper-parameters for %s" % classifiers_names[i])
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters_list[i], 
                       refit='gmean',
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True,
                      n_jobs=6)

    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f)"
              % (score, mean, std))

    print()

#     print("Detailed classification report:")
#     print()
#     print("The model is trained on the full development set.")
#     print("The scores are computed on the full evaluation set.")
#     print()
#     y_true, y_pred = y_test, clf.predict(X_test)
#     print(classification_report(y_true, y_pred))
#     print()
    pickle.dump(clf, open( "./saved_models/"+classifiers_names[i]+"_BEZ_NORM.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for RandomForestClassifier
#
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# gmean: 0.458 (+/-0.072)
#
# # Tuning hyper-parameters for AdaBoostClassifier
#
# Best parameters set found on development set:
#
# {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
#
# Grid scores on development set:
#
# gmean: 0.543 (+/-0.126)
# gmean: nan (+/-nan)
# gmean: nan (+/-nan)
# gmean: 0.284 (+/-0.247)
# gmean: nan (+/-nan)
#
# # Tuning hyper-parameters for VotingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': (('DTC', DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')), ('MLP', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)))}
#
# Grid scores on development set:
#
# gmean: 0.412 (+/-0.086)
# gmean: 0.381 (+/-0.141)
# gmean: 0.494 (+/-0.086)
# gmean: 0.176 (+/-0.115)
# gmean: 0.628 (+/-0.073)
# gmean: 0.405 (+/-0.079)
# gmean: 0.494 (+/-0.081)
# gmean: 0.555 (+/-0.086)
# gmean: 0.187 (+/-0.126)
# gmean: 0.212 (+/-0.110)
# gmean: 0.563 (+/-0.070)
#
# # Tuning hyper-parameters for StackingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': [('DTC', DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')), ('SVC', SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)), ('MLP', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)), ('QDA', QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001))]}
#
# Grid scores on development set:
#
# gmean: 0.510 (+/-0.109)
# gmean: 0.480 (+/-0.102)
# gmean: 0.218 (+/-0.149)
# gmean: 0.218 (+/-0.149)
# gmean: 0.510 (+/-0.112)
# gmean: 0.486 (+/-0.104)
# gmean: 0.000 (+/-0.000)
# gmean: 0.488 (+/-0.096)
# gmean: 0.490 (+/-0.113)
# gmean: 0.148 (+/-0.152)
# gmean: 0.494 (+/-0.094)
#
# 1172.176197528839

# %%
# VotingClassifier - oryginalne
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']

classifiers = ['[DTC,\nSVC\nMLP,\nGNB,\nQDA]',
'[DTC,\nSVC,\nMLP]',
'[DTC,\nSVC,\nGNB]',
'[DTC,\nSVC,\nQDA]',
'[DTC,\nMLP,\nGNB]',
'[DTC,\nMLP,\nQDA]',
'[DTC,\nGNB,\nQDA]',
'[SVC,\nMLP,\nGNB]',
'[SVC,\nMLP,\nQDA]',
'[SVC,\nGNB,\nQDA]',
'[MLP,\nGNB,\nQDA]']


results = [0.412,0.381,0.494,0.176,0.628,0.405,0.494,0.555,0.187,0.212,0.563]
stds = [0.086,0.141,0.086,0.115,0.073,0.079,0.081,0.086,0.126,0.110,0.070]
rect = ax.bar(classifiers,results, yerr=stds, align='center', ecolor='black', capsize=5)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2.,
                1.01*height,
                '%.3f' % float(height),
                ha='center', va='bottom')
        
autolabel(rect)
plt.title("Wartość GMEAN dla VotingClassifier z różnymi wartościami parametru estimators.")
plt.savefig("./rysunki/zad6_VotingClassifier.png",  bbox_inches = 'tight')
plt.show()

# %%
# StackingClassifier - oryginalne
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']

classifiers = ['[DTC,\nSVC\nMLP,\nGNB,\nQDA]',
'[DTC,\nSVC,\nMLP]',
'[DTC,\nSVC,\nGNB]',
'[DTC,\nSVC,\nQDA]',
'[DTC,\nMLP,\nGNB]',
'[DTC,\nMLP,\nQDA]',
'[DTC,\nGNB,\nQDA]',
'[SVC,\nMLP,\nGNB]',
'[SVC,\nMLP,\nQDA]',
'[SVC,\nGNB,\nQDA]',
'[MLP,\nGNB,\nQDA]']

results = [0.510,0.480,0.218,0.218,0.510,0.486,0.000,0.488,0.490,0.148,0.494]
stds = [0.109,0.102,0.149,0.149,0.112,0.104,0.000,0.096,0.113,0.152,0.094]
rect = ax.bar(classifiers,results, yerr=stds, align='center', ecolor='black', capsize=5)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2.,
                1.01*height,
                '%.3f' % float(height),
                ha='center', va='bottom')
        
autolabel(rect)
plt.title("Wartość GMEAN dla StackingClassifier z różnymi wartościami parametru estimators.")
plt.savefig("./rysunki/zad6_StackingClassifier.png",  bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Zadanie 7

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
# tuned_parameters = [{'clf': (RandomForestClassifier(random_state=42), )},
#                    {'clf': (AdaBoostClassifier(random_state=42), )},
#                     {'clf': (AdaBoostClassifier(random_state=42), ),
#                         'clf__base_estimator': DecisionTreeClassifier()}
#                    {'clf': (VotingClassifier(), )},
#                    {'clf': (StackingClassifier(), )}]

classifiers = [('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]

tuned_parameters_list = [{},
                         {
                             'clf__base_estimator': [DecisionTreeClassifier(random_state=42),
                                                     SVC(random_state=42),
                                                    MLPClassifier(random_state=42),
                                                    GaussianNB(),
                                                    QuadraticDiscriminantAnalysis()]
                         },
                         {
                             'clf__estimators': [[[('DTC', DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         },
                                                  {
                             'clf__estimators': [[[('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         }
                         
                   
                   ]
                   
classifiers_list = [
    RandomForestClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    VotingClassifier(n_jobs=6, estimators=[]),
    StackingClassifier(n_jobs=6, estimators=[])
    
]
classifiers_names = [
    'RandomForestClassifier',
    'AdaBoostClassifier',
    'VotingClassifier',
    'StackingClassifier'
    
]

scoring = {'gmean': make_scorer(gmean)}
score = 'gmean'


for i in range(len(classifiers_list)):
    start = time.time()
    pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf',classifiers_list[i])])
    
    print("# Tuning hyper-parameters for %s" % classifiers_names[i])
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters_list[i], 
                       refit='gmean',
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True,
                      n_jobs=6)

    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f)"
              % (score, mean, std))

    print()

#     print("Detailed classification report:")
#     print()
#     print("The model is trained on the full development set.")
#     print("The scores are computed on the full evaluation set.")
#     print()
#     y_true, y_pred = y_test, clf.predict(X_test)
#     print(classification_report(y_true, y_pred))
#     print()
    pickle.dump(clf, open( "./saved_models/"+classifiers_names[i]+"_STAND.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for RandomForestClassifier
#
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# gmean: 0.479 (+/-0.107)
#
# # Tuning hyper-parameters for AdaBoostClassifier
#
# Best parameters set found on development set:
#
# {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
#
# Grid scores on development set:
#
# gmean: 0.522 (+/-0.125)
# gmean: nan (+/-nan)
# gmean: nan (+/-nan)
# gmean: 0.328 (+/-0.249)
# gmean: nan (+/-nan)
#
# # Tuning hyper-parameters for VotingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': (('DTC', DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')), ('MLP', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)))}
#
# Grid scores on development set:
#
# gmean: 0.476 (+/-0.114)
# gmean: 0.499 (+/-0.098)
# gmean: 0.528 (+/-0.126)
# gmean: 0.256 (+/-0.175)
# gmean: 0.625 (+/-0.100)
# gmean: 0.486 (+/-0.129)
# gmean: 0.507 (+/-0.194)
# gmean: 0.554 (+/-0.094)
# gmean: 0.331 (+/-0.073)
# gmean: 0.339 (+/-0.079)
# gmean: 0.558 (+/-0.100)
#
# # Tuning hyper-parameters for StackingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': (('SVC', SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)), ('QDA', QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)))}
#
# Grid scores on development set:
#
# gmean: 0.608 (+/-0.060)
# gmean: 0.591 (+/-0.074)
# gmean: 0.608 (+/-0.061)
# gmean: 0.591 (+/-0.073)
# gmean: 0.543 (+/-0.091)
# gmean: 0.548 (+/-0.093)
# gmean: 0.000 (+/-0.000)
# gmean: 0.597 (+/-0.062)
# gmean: 0.602 (+/-0.067)
# gmean: 0.618 (+/-0.064)
# gmean: 0.536 (+/-0.096)
#
# 570.9984750747681

# %%
# VotingClassifier - oryginalne
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']

classifiers = ['[DTC,\nSVC\nMLP,\nGNB,\nQDA]',
'[DTC,\nSVC,\nMLP]',
'[DTC,\nSVC,\nGNB]',
'[DTC,\nSVC,\nQDA]',
'[DTC,\nMLP,\nGNB]',
'[DTC,\nMLP,\nQDA]',
'[DTC,\nGNB,\nQDA]',
'[SVC,\nMLP,\nGNB]',
'[SVC,\nMLP,\nQDA]',
'[SVC,\nGNB,\nQDA]',
'[MLP,\nGNB,\nQDA]']


results = [0.476, 0.499, 0.528, 0.256, 0.625, 0.486, 0.507, 0.554, 0.331, 0.339, 0.558]
stds= [0.114,0.098,0.126,0.175,0.100,0.129,0.194,0.094,0.073,0.079,0.100]
rect = ax.bar(classifiers,results, yerr=stds, align='center', ecolor='black', capsize=5)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2.,
                1.01*height,
                '%.3f' % float(height),
                ha='center', va='bottom')
        
autolabel(rect)
plt.title("Wartość GMEAN dla VotingClassifier z różnymi wartościami parametru estimators na danych przeskalowanych StandardScaler.")
plt.savefig("./rysunki/zad7_VotingClassifier_StandardScaler.png",  bbox_inches = 'tight')
plt.show()

# %%
# StackingClassifier - oryginalne
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']

classifiers = ['[DTC,\nSVC\nMLP,\nGNB,\nQDA]',
'[DTC,\nSVC,\nMLP]',
'[DTC,\nSVC,\nGNB]',
'[DTC,\nSVC,\nQDA]',
'[DTC,\nMLP,\nGNB]',
'[DTC,\nMLP,\nQDA]',
'[DTC,\nGNB,\nQDA]',
'[SVC,\nMLP,\nGNB]',
'[SVC,\nMLP,\nQDA]',
'[SVC,\nGNB,\nQDA]',
'[MLP,\nGNB,\nQDA]']

results = [0.608,0.591,0.608,0.591,0.543,0.548,0.000,0.597,0.602,0.618,0.536]
stds = [0.060,0.074,0.061,0.073,0.091,0.093,0.000,0.062,0.067,0.064,0.096]
rect = ax.bar(classifiers, results, yerr=stds, align='center', ecolor='black', capsize=5)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2.,
                1.01*height,
                '%.3f' % float(height),
                ha='center', va='bottom')
        
autolabel(rect)
plt.title("Wartość GMEAN dla StackingClassifier z różnymi wartościami parametru estimators na danych przeskalowanych StandardScaler.")
plt.savefig("./rysunki/zad7_StackingClassifier_StandardScaler.png",  bbox_inches = 'tight')
plt.show()

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
# tuned_parameters = [{'clf': (RandomForestClassifier(random_state=42), )},
#                    {'clf': (AdaBoostClassifier(random_state=42), )},
#                     {'clf': (AdaBoostClassifier(random_state=42), ),
#                         'clf__base_estimator': DecisionTreeClassifier()}
#                    {'clf': (VotingClassifier(), )},
#                    {'clf': (StackingClassifier(), )}]

classifiers = [('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]

tuned_parameters_list = [{},
                         {
                             'clf__base_estimator': [DecisionTreeClassifier(random_state=42),
                                                     SVC(random_state=42),
                                                    MLPClassifier(random_state=42),
                                                    GaussianNB(),
                                                    QuadraticDiscriminantAnalysis()]
                         },
                         {
                             'clf__estimators': [[[('DTC', DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         },
                                                  {
                             'clf__estimators': [[[('DTC',DecisionTreeClassifier(random_state=42)),
                                               ('SVC', SVC(random_state=42)),
                                               ('MLP', MLPClassifier(random_state=42)),
                                               ('GNB', GaussianNB()),
                                               ('QDA', QuadraticDiscriminantAnalysis())]] + list(it.combinations(classifiers, 3))][0]
                         }
                         
                   
                   ]
                   
classifiers_list = [
    RandomForestClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    VotingClassifier(n_jobs=6, estimators=[]),
    StackingClassifier(n_jobs=6, estimators=[])
    
]
classifiers_names = [
    'RandomForestClassifier',
    'AdaBoostClassifier',
    'VotingClassifier',
    'StackingClassifier'
    
]

scoring = {'gmean': make_scorer(gmean)}
score = 'gmean'


for i in range(len(classifiers_list)):
    start = time.time()
    pipe = Pipeline(steps=[('scaler', PowerTransformer()),('clf',classifiers_list[i])])
    
    print("# Tuning hyper-parameters for %s" % classifiers_names[i])
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters_list[i], 
                       refit='gmean',
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True,
                      n_jobs=6)

    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f)"
              % (score, mean, std))

    print()

#     print("Detailed classification report:")
#     print()
#     print("The model is trained on the full development set.")
#     print("The scores are computed on the full evaluation set.")
#     print()
#     y_true, y_pred = y_test, clf.predict(X_test)
#     print(classification_report(y_true, y_pred))
#     print()
    pickle.dump(clf, open( "./saved_models/"+classifiers_names[i]+"_POWER.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for RandomForestClassifier
#
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# gmean: 0.471 (+/-0.113)
#
# # Tuning hyper-parameters for AdaBoostClassifier
#
# Best parameters set found on development set:
#
# {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
#
# Grid scores on development set:
#
# gmean: 0.597 (+/-0.075)
# gmean: nan (+/-nan)
# gmean: nan (+/-nan)
# gmean: 0.282 (+/-0.235)
# gmean: nan (+/-nan)
#
# # Tuning hyper-parameters for VotingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': (('DTC', DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')), ('MLP', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)))}
#
# Grid scores on development set:
#
# gmean: 0.417 (+/-0.107)
# gmean: 0.417 (+/-0.107)
# gmean: 0.528 (+/-0.071)
# gmean: 0.283 (+/-0.128)
# gmean: 0.634 (+/-0.077)
# gmean: 0.402 (+/-0.100)
# gmean: 0.514 (+/-0.079)
# gmean: 0.551 (+/-0.082)
# gmean: 0.300 (+/-0.138)
# gmean: 0.300 (+/-0.138)
# gmean: 0.551 (+/-0.082)
#
# # Tuning hyper-parameters for StackingClassifier
#
# Best parameters set found on development set:
#
# {'clf__estimators': (('SVC', SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)), ('MLP', MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)), ('GNB', GaussianNB(priors=None, var_smoothing=1e-09)))}
#
# Grid scores on development set:
#
# gmean: 0.568 (+/-0.070)
# gmean: 0.567 (+/-0.078)
# gmean: 0.573 (+/-0.078)
# gmean: 0.568 (+/-0.076)
# gmean: 0.516 (+/-0.127)
# gmean: 0.503 (+/-0.130)
# gmean: 0.000 (+/-0.000)
# gmean: 0.585 (+/-0.069)
# gmean: 0.568 (+/-0.067)
# gmean: 0.558 (+/-0.068)
# gmean: 0.520 (+/-0.133)
#
# 833.0018711090088

# %% [markdown]
# # Zadanie 8

# %%
# dla SVC, GNB, QDA
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

tuned_parameters_list = [{'clf__SVC__kernel': ['linear', 'rbf', 'sigmoid'],
                         'clf__SVC__C': [0.001, 1, 100],
                         'clf__SVC__class_weight': [None, 'balanced'],
                         'clf__QDA__priors': [[0.5, 0.5], None]}
                        ]
                   
classifiers_list = [StackingClassifier(n_jobs=6, estimators=[])]
classifiers_names = ['SVC']
estimators_list = [('GNB', GaussianNB()),
                   ('SVC', SVC(random_state=42)), 
                   ('QDA', QuadraticDiscriminantAnalysis())]

# estimators_list = [
#                    ('SVC', SVC(random_state=42))
#                    ]

scoring = {'gmean': make_scorer(gmean)}
score = 'gmean'


start = time.time()
pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf', StackingClassifier(n_jobs=6, estimators=estimators_list))])

print("# Tuning hyper-parameters")
print()

clf = GridSearchCV(pipe, 
                   tuned_parameters_list, 
                   refit='gmean',
                   scoring=scoring,
                   cv=StratifiedKFold(n_splits=10, shuffle=True),
                  return_train_score=True,
                  n_jobs=6)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_{0}'.format(score)]
stds = clf.cv_results_['std_test_{0}'.format(score)]
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%s: %0.3f (+/-%0.03f) for %r"
          % (score, mean, std, params))

print()


pickle.dump(clf, open( "./saved_models/"+str(time.time())+"_BEST.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters

# %%
# dla DTC, SVC, GNB
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-ensembles.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

tuned_parameters_list = [{'clf__SVC__kernel': ['rbf', 'sigmoid'],
                         'clf__SVC__C': [0.001, 1, 100],
                         'clf__SVC__class_weight': [None, 'balanced'],
                         'clf__DTC__criterion': ['gini', 'entropy'],
                         'clf__DTC__min_samples_split': [2,8,32]}
                        ]
                   
classifiers_list = [StackingClassifier(n_jobs=6, estimators=[])]

estimators_list = [('DTC',DecisionTreeClassifier(random_state=42)),
                   ('SVC', SVC(random_state=42)), 
                   ('GNB', GaussianNB())]

# estimators_list = [
#                    ('SVC', SVC(random_state=42))
#                    ]

scoring = {'gmean': make_scorer(gmean)}
score = 'gmean'


start = time.time()
pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf', StackingClassifier(n_jobs=6, estimators=estimators_list))])

print("# Tuning hyper-parameters")
print()

clf = GridSearchCV(pipe, 
                   tuned_parameters_list, 
                   refit='gmean',
                   scoring=scoring,
                   cv=StratifiedKFold(n_splits=10, shuffle=True),
                  return_train_score=True,
                  n_jobs=6)

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_{0}'.format(score)]
stds = clf.cv_results_['std_test_{0}'.format(score)]
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%s: %0.3f (+/-%0.03f) for %r"
          % (score, mean, std, params))

print()


pickle.dump(clf, open( "./saved_models/"+str(time.time())+"_BEST.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters
#
# Best parameters set found on development set:
#
# {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
#
# Grid scores on development set:
#
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.294 (+/-0.182) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.596 (+/-0.098) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.181 (+/-0.153) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.539 (+/-0.131) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.305 (+/-0.120) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.593 (+/-0.114) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.171 (+/-0.144) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.593 (+/-0.114) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.284 (+/-0.118) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.305 (+/-0.180) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.596 (+/-0.098) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.204 (+/-0.145) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.534 (+/-0.128) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.311 (+/-0.129) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.599 (+/-0.106) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.196 (+/-0.134) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.599 (+/-0.106) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.286 (+/-0.112) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.154 (+/-0.163) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.154 (+/-0.163) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.104 (+/-0.163) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.338 (+/-0.154) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.592 (+/-0.092) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.277 (+/-0.156) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.546 (+/-0.124) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.334 (+/-0.145) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.605 (+/-0.103) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.277 (+/-0.156) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.605 (+/-0.103) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.297 (+/-0.136) for {'clf__DTC__criterion': 'gini', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.056 (+/-0.167) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.056 (+/-0.167) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.315 (+/-0.195) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.597 (+/-0.094) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.215 (+/-0.152) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.575 (+/-0.117) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.286 (+/-0.156) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.592 (+/-0.115) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.215 (+/-0.152) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.592 (+/-0.115) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.286 (+/-0.156) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 2, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.111 (+/-0.223) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.111 (+/-0.223) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.000 (+/-0.000) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.323 (+/-0.198) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.602 (+/-0.092) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.240 (+/-0.134) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.573 (+/-0.101) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.293 (+/-0.163) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.597 (+/-0.116) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.215 (+/-0.152) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.597 (+/-0.116) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.285 (+/-0.158) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 8, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.337 (+/-0.206) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.337 (+/-0.206) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.266 (+/-0.203) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.340 (+/-0.201) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 0.001, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.587 (+/-0.087) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.247 (+/-0.181) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.554 (+/-0.139) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.351 (+/-0.197) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 1, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.607 (+/-0.094) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'rbf'}
# gmean: 0.247 (+/-0.181) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': None, 'clf__SVC__kernel': 'sigmoid'}
# gmean: 0.607 (+/-0.094) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'rbf'}
# gmean: 0.344 (+/-0.159) for {'clf__DTC__criterion': 'entropy', 'clf__DTC__min_samples_split': 32, 'clf__SVC__C': 100, 'clf__SVC__class_weight': 'balanced', 'clf__SVC__kernel': 'sigmoid'}
#
# 6078.258544445038

# %%
print(time.time())
# Out:
# 1591458891.9270933

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle
from sklearn.preprocessing import PowerTransformer

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
tuned_parameters = [{'clf': (KNeighborsClassifier(), )},
                   {'clf': (DecisionTreeClassifier(random_state=42), )},
                   {'clf': (RandomForestClassifier(random_state=42), )},
                   {'clf': (SVC(random_state=42), )},
                   {'clf': (MLPClassifier(random_state=42), )},
                   {'clf': (GaussianNB(), )},
                   {'clf': (QuadraticDiscriminantAnalysis(), )},]

# tuned_parameters = [{'clf': (KNeighborsClassifier(), )},
#                    {'clf': (DecisionTreeClassifier(random_state=42), )},]

scores_list = ['AUC', 'accuracy', 'gmean']
scoring = {'AUC': 'roc_auc',
           'accuracy': make_scorer(accuracy_score),
          'gmean': make_scorer(gmean)}

pipe = Pipeline(steps=[('scaler', PowerTransformer()),('clf',SVC(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       refit=score,
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
 )
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f) for %r"
              % (score, mean, std, params))

    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    pickle.dump(clf, open( score+"_POWER.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for AUC
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)}
#
# Grid scores on development set:
#
# AUC: 0.586 (+/-0.091) for {'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')}
# AUC: 0.639 (+/-0.143) for {'clf': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
# AUC: 0.861 (+/-0.130) for {'clf': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)}
# AUC: 0.845 (+/-0.199) for {'clf': SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)}
# AUC: 0.869 (+/-0.140) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)}
# AUC: 0.748 (+/-0.153) for {'clf': GaussianNB(priors=None, var_smoothing=1e-09)}
# AUC: 0.481 (+/-0.155) for {'clf': QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.13      0.19        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.66      0.57      0.59      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)}
#
# Grid scores on development set:
#
# accuracy: 0.991 (+/-0.000) for {'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')}
# accuracy: 0.985 (+/-0.006) for {'clf': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
# accuracy: 0.991 (+/-0.001) for {'clf': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)}
# accuracy: 0.991 (+/-0.000) for {'clf': SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)}
# accuracy: 0.992 (+/-0.004) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)}
# accuracy: 0.814 (+/-0.038) for {'clf': GaussianNB(priors=None, var_smoothing=1e-09)}
# accuracy: 0.991 (+/-0.000) for {'clf': QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.13      0.19        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.66      0.57      0.59      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for gmean
#
# Best parameters set found on development set:
#
# {'clf': GaussianNB(priors=None, var_smoothing=1e-09)}
#
# Grid scores on development set:
#
# gmean: 0.038 (+/-0.227) for {'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')}
# gmean: 0.399 (+/-0.460) for {'clf': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')}
# gmean: 0.076 (+/-0.302) for {'clf': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)}
# gmean: 0.000 (+/-0.000) for {'clf': SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)}
# gmean: 0.248 (+/-0.518) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)}
# gmean: 0.650 (+/-0.305) for {'clf': GaussianNB(priors=None, var_smoothing=1e-09)}
# gmean: 0.000 (+/-0.000) for {'clf': QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.02      0.60      0.04        15
#            1       1.00      0.80      0.89      1985
#
#     accuracy                           0.80      2000
#    macro avg       0.51      0.70      0.47      2000
# weighted avg       0.99      0.80      0.88      2000
#
#
# 1915.2323725223541

# %%
file = open("gmean_STAND.pkl", "rb")
clf = pickle.load(file)
y_true, y_pred = y_test, clf.predict(X_test)
confusion_matrix(y_true, y_pred)
# Out:
# array([[   7,    8],
#        [ 303, 1682]], dtype=int64)

# %%
file = open("accuracy_STAND.pkl", "rb")
clf = pickle.load(file)
# print(clf.best_estimator_)
y_true, y_pred = y_test, clf.predict(X_test)
confusion_matrix(y_true, y_pred)
# Out:
# array([[   4,   11],
#        [   3, 1982]], dtype=int64)

# %% [markdown]
# # Zadanie 9

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
tuned_parameters = {'clf__activation': ['identity', 'logistic', 'tanh', 'relu'],
                    'clf__solver': ['lbfgs', 'sgd', 'adam']}

scores_list = ['AUC', 'accuracy', 'gmean']
scoring = {'AUC': 'roc_auc',
           'accuracy': make_scorer(accuracy_score),
          'gmean': make_scorer(gmean)}

pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf',MLPClassifier(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       refit=score,
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True)
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f) for %r"
              % (score, mean, std, params))

    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    pickle.dump(clf, open( score+"_BEST" + str(time.time()) +".pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for AUC
#
# Best parameters set found on development set:
#
# {'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# AUC: 0.816 (+/-0.080) for {'clf__activation': 'identity', 'clf__solver': 'lbfgs'}
# AUC: 0.824 (+/-0.071) for {'clf__activation': 'identity', 'clf__solver': 'sgd'}
# AUC: 0.816 (+/-0.078) for {'clf__activation': 'identity', 'clf__solver': 'adam'}
# AUC: 0.763 (+/-0.100) for {'clf__activation': 'logistic', 'clf__solver': 'lbfgs'}
# AUC: 0.562 (+/-0.070) for {'clf__activation': 'logistic', 'clf__solver': 'sgd'}
# AUC: 0.806 (+/-0.103) for {'clf__activation': 'logistic', 'clf__solver': 'adam'}
# AUC: 0.781 (+/-0.117) for {'clf__activation': 'tanh', 'clf__solver': 'lbfgs'}
# AUC: 0.838 (+/-0.090) for {'clf__activation': 'tanh', 'clf__solver': 'sgd'}
# AUC: 0.830 (+/-0.109) for {'clf__activation': 'tanh', 'clf__solver': 'adam'}
# AUC: 0.811 (+/-0.094) for {'clf__activation': 'relu', 'clf__solver': 'lbfgs'}
# AUC: 0.816 (+/-0.117) for {'clf__activation': 'relu', 'clf__solver': 'sgd'}
# AUC: 0.846 (+/-0.083) for {'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'clf__activation': 'tanh', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# accuracy: 0.991 (+/-0.002) for {'clf__activation': 'identity', 'clf__solver': 'lbfgs'}
# accuracy: 0.992 (+/-0.001) for {'clf__activation': 'identity', 'clf__solver': 'sgd'}
# accuracy: 0.991 (+/-0.002) for {'clf__activation': 'identity', 'clf__solver': 'adam'}
# accuracy: 0.989 (+/-0.003) for {'clf__activation': 'logistic', 'clf__solver': 'lbfgs'}
# accuracy: 0.991 (+/-0.000) for {'clf__activation': 'logistic', 'clf__solver': 'sgd'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'logistic', 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'tanh', 'clf__solver': 'lbfgs'}
# accuracy: 0.992 (+/-0.001) for {'clf__activation': 'tanh', 'clf__solver': 'sgd'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'tanh', 'clf__solver': 'adam'}
# accuracy: 0.991 (+/-0.003) for {'clf__activation': 'relu', 'clf__solver': 'lbfgs'}
# accuracy: 0.991 (+/-0.000) for {'clf__activation': 'relu', 'clf__solver': 'sgd'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.75      0.60      0.64      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for gmean
#
# Best parameters set found on development set:
#
# {'clf__activation': 'identity', 'clf__solver': 'lbfgs'}
#
# Grid scores on development set:
#
# gmean: 0.512 (+/-0.227) for {'clf__activation': 'identity', 'clf__solver': 'lbfgs'}
# gmean: 0.242 (+/-0.203) for {'clf__activation': 'identity', 'clf__solver': 'sgd'}
# gmean: 0.409 (+/-0.180) for {'clf__activation': 'identity', 'clf__solver': 'adam'}
# gmean: 0.411 (+/-0.176) for {'clf__activation': 'logistic', 'clf__solver': 'lbfgs'}
# gmean: 0.000 (+/-0.000) for {'clf__activation': 'logistic', 'clf__solver': 'sgd'}
# gmean: 0.389 (+/-0.221) for {'clf__activation': 'logistic', 'clf__solver': 'adam'}
# gmean: 0.401 (+/-0.231) for {'clf__activation': 'tanh', 'clf__solver': 'lbfgs'}
# gmean: 0.151 (+/-0.185) for {'clf__activation': 'tanh', 'clf__solver': 'sgd'}
# gmean: 0.383 (+/-0.230) for {'clf__activation': 'tanh', 'clf__solver': 'adam'}
# gmean: 0.480 (+/-0.110) for {'clf__activation': 'relu', 'clf__solver': 'lbfgs'}
# gmean: 0.038 (+/-0.113) for {'clf__activation': 'relu', 'clf__solver': 'sgd'}
# gmean: 0.395 (+/-0.171) for {'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.20      0.23        15
#            1       0.99      1.00      0.99      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.63      0.60      0.61      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# 888.3406927585602

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
tuned_parameters = {'clf__activation': ['relu'],
                    'clf__solver': ['adam'],
                   'clf__max_iter': [200, 1000, 5000],
                   'clf__alpha':[0.000001, 0.0001, 0.1, 100]}

scores_list = ['AUC', 'accuracy', 'gmean']
scoring = {'AUC': 'roc_auc',
           'accuracy': make_scorer(accuracy_score),
          'gmean': make_scorer(gmean)}

pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf',MLPClassifier(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       refit=score,
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True)
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f) for %r"
              % (score, mean, std, params))

    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    pickle.dump(clf, open( score+"_2_BEST_" + str(time.time()) +".pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for AUC
#
# Best parameters set found on development set:
#
# {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 200, 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# AUC: 0.847 (+/-0.070) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# AUC: 0.845 (+/-0.075) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# AUC: 0.845 (+/-0.075) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# AUC: 0.845 (+/-0.075) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# AUC: 0.639 (+/-0.128) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# AUC: 0.736 (+/-0.122) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# AUC: 0.736 (+/-0.122) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 200, 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# accuracy: 0.992 (+/-0.002) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# accuracy: 0.991 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# accuracy: 0.991 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# accuracy: 0.991 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for gmean
#
# Best parameters set found on development set:
#
# {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 200, 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 1e-06, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# gmean: 0.393 (+/-0.214) for {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# gmean: 0.405 (+/-0.225) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# gmean: 0.405 (+/-0.225) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# gmean: 0.405 (+/-0.225) for {'clf__activation': 'relu', 'clf__alpha': 0.1, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
# gmean: 0.000 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 200, 'clf__solver': 'adam'}
# gmean: 0.000 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 1000, 'clf__solver': 'adam'}
# gmean: 0.000 (+/-0.000) for {'clf__activation': 'relu', 'clf__alpha': 100, 'clf__max_iter': 5000, 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.33        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.72      0.63      0.66      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# 3190.407989025116

# %%
# %matplotlib inline
# heatmapa activation-solver-AUC 
AUC = np.array([[0.816, 0.824, 0.816],
                    [0.763, 0.562, 0.806],
                    [0.781, 0.838, 0.830],
                    [0.811, 0.816, 0.846]])
create_heatmap(values_array=AUC,
              title="Heatmapa wartości AUC",
              save_file="zad9_heatmapa_AUC.png")

# %%
# heatmapa activation-solver-accuracy 
accuracy = np.array([[0.991, 0.992, 0.991],
                    [0.989, 0.991, 0.992],
                    [0.992, 0.992, 0.992],
                    [0.991, 0.991, 0.992]])
create_heatmap(values_array=accuracy,
              title="Heatmapa wartości trafności",
              save_file="zad9_heatmapa_accuracy.png")

# %%
# heatmapa activation-solver-gmean 
gmean = np.array([[0.512, 0.242, 0.409],
                    [0.411, 0.000, 0.389],
                    [0.401, 0.151, 0.383],
                    [0.480, 0.038, 0.395]])
create_heatmap(values_array=gmean,
              title="Heatmapa wartości GMEAN",
              save_file="zad9_heatmapa_gmean.png")

# %% [markdown]
# # Zadanie 10

# %%
file = open("gmean_STAND.pkl", "rb")
clf = pickle.load(file)
# y_true, y_pred = y_test, clf.predict(X_test)
# confusion_matrix(y_true, y_pred)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.17780101, 1.60796094, 4.38225634, 0.79175088, 2.87879734,
#         0.04248583, 0.0623328 ]),
#  'std_fit_time': array([0.00865739, 0.1550799 , 0.17366434, 0.02779524, 0.15596471,
#         0.00111021, 0.00261068]),
#  'mean_score_time': array([2.27567909, 0.00397968, 0.0288276 , 0.14502831, 0.00787952,
#         0.0048876 , 0.00678632]),
#  'std_score_time': array([0.05807049, 0.00044393, 0.00070407, 0.00740706, 0.00082821,
#         0.0006984 , 0.00059958]),
#  'param_clf': masked_array(data=[KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#                     DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=42, splitter='best'),
#                     RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                         warm_start=False),
#                     SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#      max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#      verbose=False),
#                     MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                hidden_layer_sizes=(100,), learning_rate='constant',
#                learning_rate_init=0.001, max_fun=15000, max_iter=200,
#                momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#                power_t=0.5, random_state=42, shuffle=True, solver='adam',
#                tol=0.0001, validation_fraction=0.1, verbose=False,
#                warm_start=False),
#                     GaussianNB(priors=None, var_smoothing=1e-09),
#                     QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                store_covariance=False, tol=0.0001)],
#               mask=[False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                         metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                         weights='uniform')},
#   {'clf': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=42, splitter='best')},
#   {'clf': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                           warm_start=False)},
#   {'clf': SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#        decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#        max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#        verbose=False)},
#   {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                  beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                  hidden_layer_sizes=(100,), learning_rate='constant',
#                  learning_rate_init=0.001, max_fun=15000, max_iter=200,
#                  momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#                  power_t=0.5, random_state=42, shuffle=True, solver='adam',
#                  tol=0.0001, validation_fraction=0.1, verbose=False,
#                  warm_start=False)},
#   {'clf': GaussianNB(priors=None, var_smoothing=1e-09)},
#   {'clf': QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                  store_covariance=False, tol=0.0001)}],
#  'split0_test_AUC': array([0.56440281, 0.63655197, 0.99261394, 0.85876419, 0.84165015,
#         0.79625293, 0.36497928]),
#  'split1_test_AUC': array([0.49747793, 0.63781301, 0.90100883, 0.80940371, 0.85750315,
#         0.7078004 , 0.34318141]),
#  'split2_test_AUC': array([0.56764547, 0.57142857, 0.80237795, 0.96883444, 0.95910647,
#         0.70383715, 0.47883264]),
#  'split3_test_AUC': array([0.63466042, 0.63655197, 0.82057287, 0.86434877, 0.90073861,
#         0.70473789, 0.60115295]),
#  'split4_test_AUC': array([0.56323185, 0.64033507, 0.95568366, 0.94433435, 0.95027923,
#         0.71554675, 0.64132589]),
#  'split5_test_AUC': array([0.49369483, 0.49873897, 0.80832282, 0.80273825, 0.76869033,
#         0.61610521, 0.43847955]),
#  'split6_test_AUC': array([0.71248424, 0.56827599, 0.80111692, 0.59989191, 0.72563502,
#         0.84435237, 0.33201225]),
#  'split7_test_AUC': array([0.63907404, 0.63907404, 0.87020357, 0.76220501, 0.73103945,
#         0.85065754, 0.2925599 ]),
#  'split8_test_AUC': array([0.56638444, 0.71050261, 0.92740047, 0.88884886, 0.86849216,
#         0.74094758, 0.50117096]),
#  'split9_test_AUC': array([0.56386237, 0.56764547, 0.89200144, 0.74779319, 0.8063412 ,
#         0.92181589, 0.40479193]),
#  'mean_test_AUC': array([0.58029184, 0.61069177, 0.87713025, 0.82471627, 0.84094758,
#         0.76020537, 0.43984868]),
#  'std_test_AUC': array([0.06277745, 0.05607732, 0.06494049, 0.10149376, 0.07894218,
#         0.08649284, 0.11017977]),
#  'rank_test_AUC': array([6, 5, 1, 3, 2, 4, 7]),
#  'split0_train_AUC': array([0.99645709, 1.        , 1.        , 0.99999778, 1.        ,
#         0.79359742, 1.        ]),
#  'split1_train_AUC': array([0.996208  , 1.        , 1.        , 0.99999778, 1.        ,
#         0.79640527, 1.        ]),
#  'split2_train_AUC': array([0.99651714, 1.        , 1.        , 1.        , 1.        ,
#         0.79987812, 1.        ]),
#  'split3_train_AUC': array([0.99615685, 1.        , 1.        , 1.        , 1.        ,
#         0.79994373, 1.        ]),
#  'split4_train_AUC': array([0.99694194, 1.        , 1.        , 1.        , 1.        ,
#         0.79137893, 1.        ]),
#  'split5_train_AUC': array([0.99705314, 1.        , 1.        , 1.        , 1.        ,
#         0.80453861, 1.        ]),
#  'split6_train_AUC': array([0.99626916, 1.        , 1.        , 1.        , 1.        ,
#         0.79792875, 1.        ]),
#  'split7_train_AUC': array([0.99581657, 1.        , 1.        , 0.99999555, 1.        ,
#         0.79144899, 1.        ]),
#  'split8_train_AUC': array([0.99675734, 1.        , 1.        , 1.        , 1.        ,
#         0.80096568, 1.        ]),
#  'split9_train_AUC': array([0.99614684, 1.        , 1.        , 0.99999778, 1.        ,
#         0.78328896, 1.        ]),
#  'mean_train_AUC': array([0.99643241, 1.        , 1.        , 0.99999889, 1.        ,
#         0.79593745, 1.        ]),
#  'std_train_AUC': array([3.70411096e-04, 0.00000000e+00, 3.51083347e-17, 1.49193537e-06,
#         0.00000000e+00, 5.84305339e-03, 0.00000000e+00]),
#  'split0_test_accuracy': array([0.99125, 0.98125, 0.9925 , 0.99125, 0.9925 , 0.86875, 0.99125]),
#  'split1_test_accuracy': array([0.99125, 0.98375, 0.99125, 0.99125, 0.9925 , 0.86625, 0.99125]),
#  'split2_test_accuracy': array([0.99125, 0.9925 , 0.99125, 0.99125, 0.99125, 0.80375, 0.99125]),
#  'split3_test_accuracy': array([0.99125, 0.98125, 0.99125, 0.99125, 0.99   , 0.85375, 0.99125]),
#  'split4_test_accuracy': array([0.99125, 0.98875, 0.99125, 0.99125, 0.99125, 0.855  , 0.99125]),
#  'split5_test_accuracy': array([0.99125, 0.98875, 0.99125, 0.99125, 0.99125, 0.86625, 0.99125]),
#  'split6_test_accuracy': array([0.99125, 0.98625, 0.99125, 0.99125, 0.99375, 0.84875, 0.99125]),
#  'split7_test_accuracy': array([0.99125, 0.98625, 0.9925 , 0.99125, 0.99375, 0.84875, 0.99125]),
#  'split8_test_accuracy': array([0.99125, 0.9875 , 0.99125, 0.99125, 0.99375, 0.87625, 0.99125]),
#  'split9_test_accuracy': array([0.99125, 0.985  , 0.9925 , 0.99125, 0.99375, 0.81875, 0.99125]),
#  'mean_test_accuracy': array([0.99125 , 0.986125, 0.991625, 0.99125 , 0.992375, 0.850625,
#         0.99125 ]),
#  'std_test_accuracy': array([2.22044605e-16, 3.32838174e-03, 5.72821962e-04, 2.22044605e-16,
#         1.30503831e-03, 2.17316733e-02, 2.22044605e-16]),
#  'rank_test_accuracy': array([3, 6, 2, 3, 1, 7, 3]),
#  'split0_train_accuracy': array([0.99125   , 1.        , 1.        , 0.99180556, 1.        ,
#         0.86736111, 0.99583333]),
#  'split1_train_accuracy': array([0.99152778, 1.        , 1.        , 0.99194444, 1.        ,
#         0.86916667, 0.99541667]),
#  'split2_train_accuracy': array([0.99152778, 1.        , 1.        , 0.99180556, 1.        ,
#         0.77208333, 0.99583333]),
#  'split3_train_accuracy': array([0.99152778, 1.        , 1.        , 0.99208333, 1.        ,
#         0.87333333, 0.99569444]),
#  'split4_train_accuracy': array([0.99152778, 1.        , 1.        , 0.99194444, 1.        ,
#         0.86472222, 0.99569444]),
#  'split5_train_accuracy': array([0.99152778, 1.        , 0.99986111, 0.99208333, 1.        ,
#         0.86555556, 0.99597222]),
#  'split6_train_accuracy': array([0.99125   , 1.        , 1.        , 0.99180556, 1.        ,
#         0.87013889, 0.99555556]),
#  'split7_train_accuracy': array([0.99166667, 1.        , 1.        , 0.99194444, 1.        ,
#         0.83791667, 0.99569444]),
#  'split8_train_accuracy': array([0.99166667, 1.        , 1.        , 0.99194444, 1.        ,
#         0.86819444, 0.99541667]),
#  'split9_train_accuracy': array([0.99138889, 1.        , 1.        , 0.99194444, 1.        ,
#         0.82763889, 0.99541667]),
#  'mean_train_accuracy': array([0.99148611, 1.        , 0.99998611, 0.99193056, 1.        ,
#         0.85161111, 0.99565278]),
#  'std_train_accuracy': array([1.39581606e-04, 0.00000000e+00, 4.16666667e-05, 9.72222222e-05,
#         0.00000000e+00, 3.01655796e-02, 1.86855890e-04]),
#  'split0_test_gmean': array([0.        , 0.53114154, 0.37796447, 0.        , 0.53418535,
#         0.70564035, 0.        ]),
#  'split1_test_gmean': array([0.        , 0.53181945, 0.        , 0.        , 0.37796447,
#         0.70461842, 0.        ]),
#  'split2_test_gmean': array([0.        , 0.37796447, 0.        , 0.        , 0.        ,
#         0.58811872, 0.        ]),
#  'split3_test_gmean': array([0.        , 0.53114154, 0.        , 0.        , 0.        ,
#         0.6062189 , 0.        ]),
#  'split4_test_gmean': array([0.        , 0.53317268, 0.        , 0.        , 0.        ,
#         0.60666448, 0.        ]),
#  'split5_test_gmean': array([0.        , 0.        , 0.        , 0.        , 0.37772608,
#         0.35307538, 0.        ]),
#  'split6_test_gmean': array([0.        , 0.37677102, 0.        , 0.        , 0.65424077,
#         0.697423  , 0.        ]),
#  'split7_test_gmean': array([0.        , 0.53249649, 0.37796447, 0.        , 0.53452248,
#         0.697423  , 0.        ]),
#  'split8_test_gmean': array([0.        , 0.65217235, 0.        , 0.        , 0.53452248,
#         0.61418998, 0.        ]),
#  'split9_test_gmean': array([0.        , 0.37653188, 0.37796447, 0.        , 0.53452248,
#         0.83755312, 0.        ]),
#  'mean_test_gmean': array([0.        , 0.44432114, 0.11338934, 0.        , 0.35476841,
#         0.64109253, 0.        ]),
#  'std_test_gmean': array([0.        , 0.17105146, 0.17320508, 0.        , 0.24442907,
#         0.11917646, 0.        ]),
#  'rank_test_gmean': array([5, 2, 4, 5, 3, 1, 5]),
#  'split0_train_gmean': array([0.        , 1.        , 1.        , 0.25197632, 1.        ,
#         0.64395137, 0.72374686]),
#  'split1_train_gmean': array([0.17817416, 1.        , 1.        , 0.28171808, 1.        ,
#         0.63384058, 0.69006556]),
#  'split2_train_gmean': array([0.17817416, 1.        , 1.        , 0.25197632, 1.        ,
#         0.74286777, 0.72374686]),
#  'split3_train_gmean': array([0.17817416, 1.        , 1.        , 0.3086067 , 1.        ,
#         0.6461752 , 0.71269665]),
#  'split4_train_gmean': array([0.17817416, 1.        , 1.        , 0.28171808, 1.        ,
#         0.65354181, 0.71269665]),
#  'split5_train_gmean': array([0.17817416, 1.        , 0.99203175, 0.3086067 , 1.        ,
#         0.67451198, 0.73463089]),
#  'split6_train_gmean': array([0.        , 1.        , 1.        , 0.25197632, 1.        ,
#         0.64498666, 0.70147237]),
#  'split7_train_gmean': array([0.21821789, 1.        , 1.        , 0.28171808, 1.        ,
#         0.6832964 , 0.71269665]),
#  'split8_train_gmean': array([0.21821789, 1.        , 1.        , 0.28171808, 1.        ,
#         0.64426213, 0.69006556]),
#  'split9_train_gmean': array([0.12598816, 1.        , 1.        , 0.28171808, 1.        ,
#         0.6980828 , 0.69006556]),
#  'mean_train_gmean': array([0.14532947, 1.        , 0.99920317, 0.27817328, 1.        ,
#         0.66655167, 0.70918836]),
#  'std_train_gmean': array([0.0765733 , 0.        , 0.00239048, 0.01993504, 0.        ,
#         0.03207683, 0.01504901])}

# %%
# entropy
clf = DecisionTreeClassifier(random_state=42,  criterion='entropy')
clf.fit(X_train, y_train)
imp = clf.feature_importances_.copy()
sorted_desc_index = np.argsort(imp)[::-1]

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
attributes = data.columns[:-1]
for i in range(10):
    index = sorted_desc_index[i]
    print("{} - {}".format(attributes[index], imp[index]))
# Out:
# stat14 - 0.1272713839933382
# stat7 - 0.12422969451117419
# stat20 - 0.05460586788848251
# stat12 - 0.03901207372483918
# stat11 - 0.0379820813739858
# stat66 - 0.03786533916767583
# stat24 - 0.035417988213770416
# stat15 - 0.03334762051320418
# stat32 - 0.029832979605985462
# stat45 - 0.02870004775914598

# %%
# gini
clf = DecisionTreeClassifier(random_state=42,  criterion='gini')
clf.fit(X_train, y_train)
imp = clf.feature_importances_.copy()
sorted_desc_index = np.argsort(imp)[::-1]

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
attributes = data.columns[:-1]
for i in range(10):
    index = sorted_desc_index[i]
    print("{} - {}".format(attributes[index], imp[index]))
# Out:
# stat8 - 0.12573095941089615
# stat54 - 0.05470070306133859
# stat14 - 0.05312814356263773
# stat13 - 0.050096257712578515
# stat15 - 0.04887084332229356
# stat22 - 0.04562165187559479
# stat25 - 0.03904785775267401
# stat6 - 0.03857587774404684
# stat19 - 0.03741388187773583
# el22 - 0.036511704303411156

# %% [markdown]
# # Zadanie 11

# %%
data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

zero_to_all_ratio = collections.Counter(y_train)[0]/len(y_train)
class_weights = [None,
                 {0:1, 1:1}, 
                 'balanced',
                 {0:(1-zero_to_all_ratio), 1:zero_to_all_ratio},
                 {0:0.75, 1:25},
                 {0:zero_to_all_ratio, 1:(1-zero_to_all_ratio)}
                ]
for class_weight in class_weights:
    clf = DecisionTreeClassifier(random_state=42,  
                                 criterion='gini',
                                class_weight=class_weight)

    pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf', clf)])
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)

    print('===================================')
    print(class_weight)
    print(confusion_matrix(y_test, y_pred))
# Out:
# ===================================
# None
# [[   0   15]
#  [  17 1968]]
# ===================================
# {0: 1, 1: 1}
# [[   0   15]
#  [  17 1968]]
# ===================================
# balanced
# [[   3   12]
#  [  16 1969]]
# ===================================
# {0: 0.99125, 1: 0.00875}
# [[   3   12]
#  [  12 1973]]
# ===================================
# {0: 0.75, 1: 25}
# [[   3   12]
#  [  29 1956]]
# ===================================
# {0: 0.25, 1: 75}
# [[   3   12]
#  [  29 1956]]
# ===================================
# {0: 0.00875, 1: 0.99125}
# [[   3   12]
#  [  25 1960]]

# %% [markdown]
# # Zadanie 12 - najlepszy model MLPClassifier(solver='adam', activation='relu')

# %%
# ze standaryzacją
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
tuned_parameters = {'clf': [MLPClassifier(random_state=42)],
                    'clf__activation': ['relu'],
                    'clf__solver': ['adam']}

scores_list = ['AUC', 'accuracy', 'gmean']
scoring = {'AUC': 'roc_auc',
           'accuracy': make_scorer(accuracy_score),
          'gmean': make_scorer(gmean)}

pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf',MLPClassifier(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       refit=score,
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True)
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f) for %r"
              % (score, mean, std, params))

    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
#     pickle.dump(clf, open( score+"_2_BEST_" + str(time.time()) +".pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for AUC
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# AUC: 0.838 (+/-0.120) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# accuracy: 0.992 (+/-0.001) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for gmean
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# gmean: 0.377 (+/-0.209) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.27      0.36        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.78      0.63      0.68      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# 140.92893886566162

# %%
# bez standaryzacji
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle

from imblearn.metrics import geometric_mean_score as gmean

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
 

# Set the parameters by cross-validation
tuned_parameters = {'clf': [MLPClassifier(random_state=42)],
                    'clf__activation': ['relu'],
                    'clf__solver': ['adam']}

scores_list = ['AUC', 'accuracy', 'gmean']
scoring = {'AUC': 'roc_auc',
           'accuracy': make_scorer(accuracy_score),
          'gmean': make_scorer(gmean)}

pipe = Pipeline(steps=[('clf',MLPClassifier(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       refit=score,
                       scoring=scoring,
                       cv=StratifiedKFold(n_splits=10, shuffle=True),
                      return_train_score=True)
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_{0}'.format(score)]
    stds = clf.cv_results_['std_test_{0}'.format(score)]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%s: %0.3f (+/-%0.03f) for %r"
              % (score, mean, std, params))

    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
#     pickle.dump(clf, open( score+"_2_BEST_" + str(time.time()) +".pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for AUC
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# AUC: 0.759 (+/-0.055) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.07      0.11        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.62      0.53      0.55      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# accuracy: 0.991 (+/-0.001) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.07      0.11        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.62      0.53      0.55      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# # Tuning hyper-parameters for gmean
#
# Best parameters set found on development set:
#
# {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Grid scores on development set:
#
# gmean: 0.285 (+/-0.247) for {'clf': MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False), 'clf__activation': 'relu', 'clf__solver': 'adam'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.07      0.11        15
#            1       0.99      1.00      1.00      1985
#
#     accuracy                           0.99      2000
#    macro avg       0.62      0.53      0.55      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# 355.3697340488434

# %%
# macierz pomyłek
clf = pickle.load(open("./auc_BEST.pkl", 'rb'))

best = clf.best_estimator_
print(best)

data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

y_pred = best.predict(X_test)
# print('accuracy')
# print(confusion_matrix(y_test, y_pred))



# titles_options = [("Macierz pomyłek, bez normalizacji", None),
#                   ("Macierz pomyłek, z normalizacją", 'true'),
#                  ("Macierz pomyłek, ze standaryzacją", 'true')]

disp = plot_confusion_matrix(best, X_test, y_test,
                                 display_labels=[0, 1],
                                 cmap=plt.cm.Blues, 
                                 values_format='d')

disp.ax_.set_title("Macierz pomyłek")
plt.savefig('./rysunki/zad12_confusion_matrix_BEST.png')

plt.show()
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('clf',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(100,),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=200, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=42, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
data = pd.read_csv("./131767-imbalanced.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

zero_to_all_ratio = collections.Counter(y_train)[0]/len(y_train)
class_weights = [None,
                 {0:1, 1:1}, 
                 'balanced',
                 {0:(1-zero_to_all_ratio), 1:zero_to_all_ratio},
                 {0:0.75, 1:25},
                 {0:zero_to_all_ratio, 1:(1-zero_to_all_ratio)},
                ]
for class_weight in class_weights:
    clf = SVC(random_state=42,  
              class_weight=class_weight)

    pipe = Pipeline(steps=[('scaler', StandardScaler()),('clf', clf)])
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)

    print('===================================')
    print(class_weight)
    print(confusion_matrix(y_test, y_pred))
# Out:
# ===================================
# None
# [[   0   15]
#  [   0 1985]]
# ===================================
# {0: 1, 1: 1}
# [[   0   15]
#  [   0 1985]]
# ===================================
# balanced
# [[   5   10]
#  [   5 1980]]
# ===================================
# {0: 0.99125, 1: 0.00875}
# [[  10    5]
#  [ 241 1744]]
# ===================================
# {0: 0.75, 1: 25}
# [[   0   15]
#  [   0 1985]]
# ===================================
# {0: 0.25, 1: 75}
# [[   0   15]
#  [   0 1985]]
# ===================================
# {0: 0.00875, 1: 0.99125}
# [[   0   15]
#  [   0 1985]]

# %%
collections.Counter(y_train)
# Out:
# Counter({1: 7930, 0: 70})

# %%
# best estimator
clf_acc = pickle.load(open("./accuracy_BEZ_LINEAR.pkl", 'rb'))
clf_bal_acc = pickle.load(open("./balanced_accuracy_BEZ_LINEAR.pkl", 'rb'))

best_acc = clf_acc.best_estimator_
best_bal_acc = clf_bal_acc.best_estimator_

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

y_pred = best_acc.predict(X_test)
# print('accuracy')
# print(confusion_matrix(y_test, y_pred))

y_pred = best_bal_acc.predict(X_test)
# print('balanced accuracy')
# print(confusion_matrix(y_test, y_pred))

# titles_options = [("Macierz pomyłek, bez normalizacji", None),
#                   ("Macierz pomyłek, z normalizacją", 'true'),
#                  ("Macierz pomyłek, ze standaryzacją", 'true')]

disp = plot_confusion_matrix(best_acc, X_test, y_test,
                                 display_labels=[0, 1],
                                 cmap=plt.cm.Blues, 
                                 values_format='d')

disp.ax_.set_title("Macierz pomyłek, bez normalizacji")
plt.savefig('./rysunki/zad8_confusion_matrix_BEZ_NORM.png')

plt.show()

# %% [markdown]
# # Zadanie 10

# %%
# NORMALIZACJA
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle
from sklearn.preprocessing import Normalizer, StandardScaler

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)


# Set the parameters by cross-validation
tuned_parameters = {'svc__kernel':('rbf', 'sigmoid'),
              'svc__C':[1, 10, 100, 1000],
            'svc__class_weight':['balanced']}

scores_list = ['accuracy', 'balanced_accuracy']
pipe = Pipeline(steps=[('scaler', Normalizer()), ('svc',SVC(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       scoring=score,
                       cv=StratifiedKFold(n_splits=10, shuffle=True))
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    pickle.dump(clf, open( score+str(time.time())+"BEZ_LINEAR_NORM_BALANCED_SHUFFLE_PIPE.pkl", "wb" ) )

    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.780 (+/-0.034) for {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.429 (+/-0.026) for {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.794 (+/-0.026) for {'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.421 (+/-0.026) for {'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.805 (+/-0.026) for {'svc__C': 100, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.421 (+/-0.027) for {'svc__C': 100, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.821 (+/-0.027) for {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.421 (+/-0.027) for {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      2248
#            1       0.62      0.78      0.69       752
#
#     accuracy                           0.82      3000
#    macro avg       0.77      0.81      0.78      3000
# weighted avg       0.84      0.82      0.83      3000
#
#
# # Tuning hyper-parameters for balanced_accuracy
#
# Best parameters set found on development set:
#
# {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.761 (+/-0.039) for {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.425 (+/-0.028) for {'svc__C': 1, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.779 (+/-0.032) for {'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.421 (+/-0.028) for {'svc__C': 10, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.792 (+/-0.033) for {'svc__C': 100, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.422 (+/-0.028) for {'svc__C': 100, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
# 0.809 (+/-0.031) for {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'rbf'}
# 0.421 (+/-0.028) for {'svc__C': 1000, 'svc__class_weight': 'balanced', 'svc__kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      2248
#            1       0.62      0.78      0.69       752
#
#     accuracy                           0.82      3000
#    macro avg       0.77      0.81      0.78      3000
# weighted avg       0.84      0.82      0.83      3000
#
#
# 4258.582862138748

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score
y_true, y_pred = y_test, clf.predict(X_test)
print(accuracy_score(y_true, y_pred))
print(balanced_accuracy_score(y_true, y_pred))
print(confusion_matrix(y_true, y_pred))

# 0.958 - specifity
# 0.527 - sensivity - recall
# Out:
# 0.8503333333333334
# 0.7430552926478383
# [[2154   94]
#  [ 355  397]]

# %%
# heatmapa accuracy - NORMALIZACJA, BALANCED
accuracy = np.array([[0.780, 0.794, 0.805, 0.821],
                    [0.429, 0.421, 0.421, 0.421]])
create_heatmap(values_array=accuracy,
              title="Heatmapa wartości trafności",
               param="normalizacja, class_weight='balanced'",
              save_file="zad10_heatmapa_acc_NORM_BALANCED.png")

# %%
# heatmapa accuracy - NORMALIZACJA, NONE
accuracy = np.array([[0.798, 0.821, 0.831, 0.845],
                    [0.633, 0.613, 0.646, 0.628]])
create_heatmap(values_array=accuracy,
              title="Heatmapa wartości trafności",
               param='normalizacja, class_weight=None',
              save_file="zad10_heatmapa_acc_NORM_None.png")

# %%
#############
# heatmapa balanced_accuracy - NORMALIZACJA, None
balanced_accuracy = np.array([[0.625, 0.676, 0.704, 0.744],
                    [0.499, 0.496, 0.545, 0.518]])
create_heatmap(values_array=balanced_accuracy,
              title="Heatmapa wartości zbalansowanej trafności",
               param="normalizacja, class_weight=None",
              save_file="zad10_heatmapa_bal_acc_NORM_None.png")

# %%
# heatmapa balanced_accuracy - NORMALIZACJA, BALANCED
balanced_accuracy = np.array([[0.761, 0.779, 0.792, 0.809],
                    [0.425, 0.421, 0.422, 0.421]])
create_heatmap(values_array=balanced_accuracy,
              title="Heatmapa wartości zbalansowanej trafności",
               param="normalizacja, class_weight='balanced'",
              save_file="zad10_heatmapa_bal_acc_NORM_BALANCED.png")

# %%
# best estimator 
clf_acc = pickle.load(open("./pkl_z_pipeline/accuracy_BEZ_LINEAR_NORM_None_PIPE.pkl", 'rb'))
clf_bal_acc = pickle.load(open("./balanced_accuracy_BEZ_LINEAR_NORM.pkl", 'rb'))

best_acc = clf_acc.best_estimator_
best_bal_acc = clf_bal_acc.best_estimator_

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

norm = Normalizer()
X_train = norm.transform(X_train)
X_test = norm.transform(X_test)

y_pred = best_acc.predict(X_test)
print('accuracy')
print(confusion_matrix(y_test, y_pred))

y_pred = best_bal_acc.predict(X_test)
print('balanced accuracy')
print(confusion_matrix(y_test, y_pred))

disp = plot_confusion_matrix(best_acc, X_test, y_test,
                                 display_labels=[0, 1],
                                 cmap=plt.cm.Blues, 
                                 values_format='d')

disp.ax_.set_title("Macierz pomyłek, z normalizacją")
plt.savefig('./rysunki/zad10_confusion_matrix_NORM_NONE.png')

plt.show()
# Out:
# accuracy
# [[2154   94]
#  [ 355  397]]
# balanced accuracy
# [[2154   94]
#  [ 355  397]]

# %%
# best estimator Z SHUFFLE
clf_acc = pickle.load(open("./pkl_z_pipeline/accuracy_BEZ_LINEAR_NORM_None_SHUFFLE_PIPE.pkl", 'rb'))
clf_bal_acc = pickle.load(open("./balanced_accuracy_BEZ_LINEAR_NORM.pkl", 'rb'))

best_acc = clf_acc.best_estimator_
best_bal_acc = clf_bal_acc.best_estimator_

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

norm = Normalizer()
X_train = norm.transform(X_train)
X_test = norm.transform(X_test)

y_pred = best_acc.predict(X_test)
print('accuracy')
print(confusion_matrix(y_test, y_pred))

y_pred = best_bal_acc.predict(X_test)
print('balanced accuracy')
print(confusion_matrix(y_test, y_pred))

disp = plot_confusion_matrix(best_acc, X_test, y_test,
                                 display_labels=[0, 1],
                                 cmap=plt.cm.Blues, 
                                 values_format='d')

disp.ax_.set_title("Macierz pomyłek, z normalizacją")
plt.savefig('./rysunki/zad10_confusion_matrix_NORM_NONE_SHUFFLE.png')

plt.show()
# Out:
# accuracy
# [[2154   94]
#  [ 355  397]]
# balanced accuracy
# [[2154   94]
#  [ 355  397]]

# %%
# STANDARYZACJA
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score
import time
import pickle
from sklearn.preprocessing import Normalizer, StandardScaler

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# sca = StandardScaler()
# X_train = sca.fit_transform(X_train)
# X_test = sca.transform(X_test)


# Set the parameters by cross-validation
tuned_parameters = {'svc__kernel':('rbf', 'sigmoid'),
              'svc__C':[1, 10, 100, 1000],
            'svc__class_weight':[None]}

scores_list = ['accuracy', 'balanced_accuracy']
pipe = Pipeline(steps=[('scaler', StandardScaler()), ('svc',SVC(random_state=42))])

start = time.time()
for score in scores_list:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(pipe, 
                       tuned_parameters, 
                       scoring=score,
                       cv=StratifiedKFold(n_splits=10, shuffle=True))
    
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    pickle.dump(clf, open( score+str(time.time())+"BEZ_LINEAR_STAND_None_SHUFFLE_PIPE.pkl", "wb" ) )
    
print(time.time()-start)
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'svc__C': 10, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.860 (+/-0.021) for {'svc__C': 1, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.696 (+/-0.022) for {'svc__C': 1, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.887 (+/-0.015) for {'svc__C': 10, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.693 (+/-0.021) for {'svc__C': 10, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.883 (+/-0.013) for {'svc__C': 100, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.693 (+/-0.021) for {'svc__C': 100, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.882 (+/-0.012) for {'svc__C': 1000, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.693 (+/-0.020) for {'svc__C': 1000, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      2248
#            1       0.82      0.72      0.77       752
#
#     accuracy                           0.89      3000
#    macro avg       0.87      0.83      0.85      3000
# weighted avg       0.89      0.89      0.89      3000
#
#
# # Tuning hyper-parameters for balanced_accuracy
#
# Best parameters set found on development set:
#
# {'svc__C': 1000, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.762 (+/-0.025) for {'svc__C': 1, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.603 (+/-0.029) for {'svc__C': 1, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.828 (+/-0.026) for {'svc__C': 10, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.601 (+/-0.035) for {'svc__C': 10, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.842 (+/-0.025) for {'svc__C': 100, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.600 (+/-0.032) for {'svc__C': 100, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
# 0.843 (+/-0.026) for {'svc__C': 1000, 'svc__class_weight': None, 'svc__kernel': 'rbf'}
# 0.601 (+/-0.032) for {'svc__C': 1000, 'svc__class_weight': None, 'svc__kernel': 'sigmoid'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      2248
#            1       0.78      0.76      0.77       752
#
#     accuracy                           0.89      3000
#    macro avg       0.85      0.84      0.85      3000
# weighted avg       0.89      0.89      0.89      3000
#
#
# 2411.433516740799

# %%
# heatmapa accuracy - STANDARYZACJA, NONE
accuracy = np.array([[0.863, 0.886, 0.882, 0.880],
                    [0.696, 0.692, 0.692, 0.692]])
create_heatmap(values_array=accuracy,
              title="Heatmapa wartości trafności",
               param="standaryzacja, class_weight=None",
              save_file="zad10_heatmapa_acc_STAND_NONE.png")

# %%
# heatmapa accuracy - STANDARYZACJA, BALANCED
accuracy = np.array([[0.845, 0.879, 0.881, 0.880],
                    [0.651, 0.647, 0.647, 0.647]])
create_heatmap(values_array=accuracy,
              title="Heatmapa wartości trafności",
               param="standaryzacja, class_weight='balanced'",
              save_file="zad10_heatmapa_acc_STAND_BALANCED.png")

# %%
# heatmapa balanced_accuracy - STANDARYZACJA, NONE
balanced_accuracy = np.array([[0.763, 0.828, 0.839, 0.837],
                    [0.604, 0.601, 0.602, 0.601]])
create_heatmap(values_array=balanced_accuracy,
              title="Heatmapa wartości zbalansowanej trafności",
               param="standaryzacja, class_weight=None",
              save_file="zad10_heatmapa_bal_acc_STAND_NONE.png")

# %%
# heatmapa balanced_accuracy - STANDARYZACJA, BALANCED
balanced_accuracy = np.array([[0.842, 0.859, 0.839, 0.837],
                    [0.654, 0.648, 0.648, 0.647]])
create_heatmap(values_array=balanced_accuracy,
              title="Heatmapa wartości zbalansowanej trafności",
               param="standaryzacja, class_weight='balanced'",
              save_file="zad10_heatmapa_bal_acc_STAND_BALANCED.png")

# %%
# best estimator 
clf_acc = pickle.load(open("./accuracy_BEZ_LINEAR_STAND.pkl", 'rb'))
clf_bal_acc = pickle.load(open("./balanced_accuracy_BEZ_LINEAR_STAND.pkl", 'rb'))


best_acc = clf_acc.best_estimator_
best_bal_acc = clf_bal_acc.best_estimator_

data = pd.read_csv("./131767-svm.txt", sep='\t')
data[:3]
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

sca = StandardScaler()
X_train = sca.fit_transform(X_train)
X_test = sca.transform(X_test)

y_pred = best_acc.predict(X_test)
print('accuracy')
print(confusion_matrix(y_test, y_pred))

y_pred = best_bal_acc.predict(X_test)
print('balanced accuracy')
print(confusion_matrix(y_test, y_pred))

disp = plot_confusion_matrix(best_acc, X_test, y_test,
                                 display_labels=[0, 1],
                                 cmap=plt.cm.Blues, 
                                 values_format='d')

disp.ax_.set_title("Macierz pomyłek, ze standaryzacją")
plt.savefig('./rysunki/zad10_confusion_matrix_STAND_NONE.png')

plt.show()
# Out:
# accuracy
# [[2130  118]
#  [ 209  543]]
# balanced accuracy
# [[2092  156]
#  [ 180  572]]

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score as gmean
from skleanr.model_selection import KFold

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
clf = SVC(random_state=42)
clf.fit(X_train, y_train)


y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
print("balanced_accuracy_score: ", balanced_accuracy_score(y_test, y_pred, adjusted=False))
print(gmean(y_test, y_pred))

# %%
# standarycja, bez użycia PCA
sca = StandardScaler()
X_train_std = sca.fit_transform(X_train)
X_test_std = sca.transform(X_test)

clf = LinearSVC(random_state=42)
clf.fit(X_train_std, y_train)


y_pred = clf.predict(X_test_std)
print(classification_report(y_test, y_pred))
print("balanced_accuracy_score: ", balanced_accuracy_score(y_test, y_pred, adjusted=False))

# %%
# standaryzacja, PCA 3 wymiary
sca = StandardScaler()
X_train_std = sca.fit_transform(X_train)
X_test_std = sca.transform(X_test)

pca = PCA(n_components=119, random_state=42)
X_train_std_pca = pca.fit_transform(X_train_std)
X_test_std_pca = pca.transform(X_test_std)
print("explained_variance_ratio_: ", sum(pca.explained_variance_ratio_))

clf = SVC(random_state=42)
clf.fit(X_train_std_pca, y_train)


y_pred = clf.predict(X_test_std_pca)
print(classification_report(y_test, y_pred))
print("balanced_accuracy_score: ", balanced_accuracy_score(y_test, y_pred, adjusted=False))

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        SVC(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()

# Note the problem is too easy: the hyperparameter plateau is too flat and the
# output model is the same for precision and recall with ties in quality.

# %%
clf.cv_results_

# %%
import json
id = 1
username = 'maciej'
password = "sdfsffsd"

f = {"id": id, "username": username, "password": password}
jsonify(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-163546d25722> in <module>
#       5
#       6 f = {"id": id, "username": username, "password": password}
# ----> 7 jsonify(f)
#
# NameError: name 'jsonify' is not defined
